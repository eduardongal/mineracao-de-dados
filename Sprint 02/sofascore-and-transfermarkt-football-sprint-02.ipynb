# %%
import numpy as np 
import pandas as pd 

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/sofascore-and-transfermarkt-football-data/statistics_player.csv
# /kaggle/input/sofascore-and-transfermarkt-football-data/partidas_sofascore.csv
# /kaggle/input/sofascore-and-transfermarkt-football-data/players_tm.csv
# /kaggle/input/sofascore-and-transfermarkt-football-data/statistics_game.csv
# /kaggle/input/sofascore-and-transfermarkt-football-data/performance_tm.csv
# /kaggle/input/sofascore-and-transfermarkt-football-data/market_value.csv

# %% [markdown]
# ###  📊 Carregar dados

# %%
dados_valores_mercado = pd.read_csv('/kaggle/input/sofascore-and-transfermarkt-football-data/market_value.csv')
dados_partidas = pd.read_csv('/kaggle/input/sofascore-and-transfermarkt-football-data/partidas_sofascore.csv')
dados_desempenho_jogadores = pd.read_csv('/kaggle/input/sofascore-and-transfermarkt-football-data/performance_tm.csv')
dados_jogadores = pd.read_csv('/kaggle/input/sofascore-and-transfermarkt-football-data/players_tm.csv')
dados_estatisticas_partidas = pd.read_csv('/kaggle/input/sofascore-and-transfermarkt-football-data/statistics_game.csv')
dados_estatisticas_jogadores = pd.read_csv('/kaggle/input/sofascore-and-transfermarkt-football-data/statistics_player.csv')

# %% [markdown]
# ###  👁️ Visualização das primeiras linhas de cada dataset
#
# Nesta etapa, realizamos a visualização inicial das primeiras linhas de cada dataset.

# %%
dados_valores_mercado.head()
# Out:
#               x         y     mw      datum_mw                  verein  age  \
# 0  1.202425e+12   50000.0   €50k   Feb 8, 2008  Cruzeiro Esporte Clube   18
# 1  1.229036e+12  200000.0  €200k  Dec 12, 2008  Cruzeiro Esporte Clube   19
# 2  1.254694e+12  800000.0  €800k   Oct 5, 2009  Cruzeiro Esporte Clube   20
# 3  1.271282e+12  600000.0  €600k  Apr 15, 2010  Cruzeiro Esporte Clube   20
# 4  1.275775e+12  300000.0  €300k   Jun 6, 2010  Cruzeiro Esporte Clube   20
#
#                                               wappen  player_id player_name
# 0  https://tmssl.akamaized.net//images/wappen/pro...      68097      Rafael
# 1                                                NaN      68097      Rafael
# 2                                                NaN      68097      Rafael
# 3                                                NaN      68097      Rafael
# 4                                                NaN      68097      Rafael

# %%
dados_partidas.head()
# Out:
#          Data           Campeonato  ID da Partida
# 0  2024-10-02       Copa do Brasil       12903983
# 1  2024-10-02       Copa do Brasil       12903984
# 2  2024-10-03  Brasileirão Série A       12117263
# 3  2024-10-03  Brasileirão Série A       12117257
# 4  2024-10-03  Brasileirão Série B       12146484

# %%
dados_desempenho_jogadores.head()
# Out:
#                                    detailedStatsLink  \
# 0  /rafael/leistungsdatendetails/spieler/68097/we...
# 1  /rafael/leistungsdatendetails/spieler/68097/we...
# 2  /rafael/leistungsdatendetails/spieler/68097/we...
# 3  /rafael/leistungsdatendetails/spieler/68097/we...
# 4  /rafael/leistungsdatendetails/spieler/68097/we...
#
#          competitionDescription  \
# 0                       Série A
# 1                Copa do Brasil
# 2                 Supercopa Rei
# 3                  Libertadores
# 4  Paulistão A1 - Primeira Fase
#
#                                                 logo nameSeason  \
# 0  https://tmssl.akamaized.net//images/logo/norma...       2024
# 1  https://tmssl.akamaized.net//images/logo/norma...       2024
# 2  https://tmssl.akamaized.net//images/logo/norma...       2024
# 3  https://tmssl.akamaized.net//images/logo/norma...       2024
# 4  https://tmssl.akamaized.net//images/logo/norma...       2024
#
# ...

# %%
dados_jogadores.head()
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#                      Clube  Nome  \
# 0  São Paulo Futebol Clube   NaN
# 1  São Paulo Futebol Clube   NaN
# 2  São Paulo Futebol Clube   NaN
# 3  São Paulo Futebol Clube   NaN
# 4  São Paulo Futebol Clube   NaN
#
#                                        URL do perfil      ID
# 0  https://www.transfermarkt.com/rafael/profil/sp...   68097
# 1  https://www.transfermarkt.com/jandrei/profil/s...  512344
# ...

# %%
dados_estatisticas_partidas.head()
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
#    id_partida   data_jogo           campeonato  home_team    away_team period  \
# 0    12117250  2024-09-29  Brasileirão Série A  São Paulo  Corinthians    ALL
# 1    12117250  2024-09-29  Brasileirão Série A  São Paulo  Corinthians    ALL
# 2    12117250  2024-09-29  Brasileirão Série A  São Paulo  Corinthians    ALL
# 3    12117250  2024-09-29  Brasileirão Série A  São Paulo  Corinthians    ALL
# ...

# %%
dados_estatisticas_jogadores.head()
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in greater
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1458: RuntimeWarning: invalid value encountered in greater
#   has_large_values = (abs_vals > 1e6).any()
# /usr/local/lib/python3.11/dist-packages/pandas/io/formats/format.py:1459: RuntimeWarning: invalid value encountered in less
#   has_small_values = ((abs_vals < 10 ** (-self.digits)) & (abs_vals > 0)).any()
# ...

# %% [markdown]
# ###  📊 Dimensão dos Datasets: Registros e Variáveis
#
# * Nesta etapa, é apresentada a quantidade total de registros (linhas) e variáveis (colunas) presentes em cada dataset

# %%
print("dados_valores_mercado: ", dados_valores_mercado.shape)
print("dados_partidas:", dados_partidas.shape)
print("dados_desempenho_jogadores:", dados_desempenho_jogadores.shape)
print("dados_jogadores:", dados_jogadores.shape)
print("dados_estatisticas_partidas:", dados_estatisticas_partidas.shape)
print("dados_estatisticas_jogadores:", dados_estatisticas_jogadores.shape)
# Out:
# dados_valores_mercado:  (33043, 9)
# dados_partidas: (634, 3)
# dados_desempenho_jogadores: (9596, 22)
# dados_jogadores: (2729, 4)
# dados_estatisticas_partidas: (102690, 15)
# dados_estatisticas_jogadores: (39861, 53)

# %% [markdown]
# ### 🔍 Verificação dos Tipos de Variáveis
#
# * Nesta etapa, são verificados os tipos de dados de cada variável do dataset. Essa análise é útil para validar a estrutura dos dados e garantir que cada variável esteja no formato adequado para as próximas etapas da análise.

# %%
dados_valores_mercado.dtypes
# Out:
# x              float64
# y              float64
# mw              object
# datum_mw        object
# verein          object
# age              int64
# wappen          object
# player_id        int64
# player_name     object
# dtype: object

# %%
dados_partidas.dtypes
# Out:
# Data             object
# Campeonato       object
# ID da Partida     int64
# dtype: object

# %%
dados_desempenho_jogadores.dtypes
# Out:
# detailedStatsLink           object
# competitionDescription      object
# logo                        object
# nameSeason                  object
# possibleGames              float64
# gamesPlayed                float64
# goalsScored                float64
# assists                    float64
# yellowCards                float64
# secondYellowCards          float64
# redCards                   float64
# startElevenPercent         float64
# minutesPlayedPercent       float64
# goalsContributedPercent    float64
# goalkeeper                    bool
# concededGoals              float64
# cleanSheets                float64
# blockedPenaltyPercent      float64
# minutesPlayed              float64
# player_id                    int64
# player_name                 object
# player_number              float64
# dtype: object

# %%
dados_jogadores.dtypes
# Out:
# Clube             object
# Nome             float64
# URL do perfil     object
# ID                 int64
# dtype: object

# %%
dados_estatisticas_partidas.dtypes
# Out:
# id_partida        int64
# data_jogo        object
# campeonato       object
# home_team        object
# away_team        object
# period           object
# group            object
# name             object
# home_value      float64
# away_value      float64
# home_total      float64
# away_total      float64
# compare_code      int64
# key              object
# resultado        object
# dtype: object

# %%
dados_estatisticas_jogadores.dtypes
# Out:
# id_partida                      int64
# data_jogo                      object
# campeonato                     object
# team                           object
# team_name                      object
# name                           object
# position                       object
# jerseyNumber                  float64
# height                        float64
# country                        object
# dateOfBirth                    object
# age                           float64
# totalPass                     float64
# accuratePass                  float64
# totalLongBalls                float64
# accurateLongBalls             float64
# goalAssist                    float64
# goals                         float64
# minutesPlayed                 float64
# rating                        float64
# touches                       float64
# possessionLostCtrl            float64
# expectedGoals                 float64
# expectedAssists               float64
# aerialLost                    float64
# ...

# %% [markdown]
# ###  Classificação das variáveis e geração de tabela resumo
#
# * Nesta etapa, as variáveis do dataset foram classificadas em dois grupos principais: quantitativas (numéricas) e qualitativas (categóricas). Em seguida, foi gerada uma tabela resumo que apresenta, lado a lado, os nomes das variáveis conforme o tipo, facilitando a visualização e análise dos dados.

# %%
import pandas as pd

# Função para classificar variáveis
def classificar_variaveis(df):
    quantitativas = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
    qualitativas = df.select_dtypes(include=['object', 'category', 'bool']).columns.tolist()
    return quantitativas, qualitativas

# %%
def gerar_tabela_resumo(quantitativas, qualitativas):
    max_len = max(len(quantitativas), len(qualitativas))
    qnt_pad = quantitativas + [""] * (max_len - len(quantitativas))
    qlt_pad = qualitativas + [""] * (max_len - len(qualitativas))
    
    tabela = pd.DataFrame({
        "Variáveis Quantitativas": qnt_pad,
        "Variáveis Qualitativas": qlt_pad
    })
    return tabela

# %%
def exibir_dataset_classificado(nome_dataset, df):
    # Classificação
    quantitativas, qualitativas = classificar_variaveis(df)
    
    # Título
    print(f"\n📋 Dataset: {nome_dataset}")
    
    # Tamanho
    print(f"\n📊 Total: {df.shape[0]} linhas e {df.shape[1]} colunas")
    
    # Listas
    print("\n▶ Variáveis Quantitativas:", quantitativas)
    print("▶ Variáveis Qualitativas:", qualitativas)
    
    # Tabela resumo
    tabela_resumo = gerar_tabela_resumo(quantitativas, qualitativas)
    print("\n\n📋 Tabela Resumo:")
    print(tabela_resumo)

# %%
exibir_dataset_classificado('dados_valores_mercado',dados_valores_mercado)
# Out:
# 📋 Dataset: dados_valores_mercado
#
# 📊 Total: 33043 linhas e 9 colunas
#
# ▶ Variáveis Quantitativas: ['x', 'y', 'age', 'player_id']
# ▶ Variáveis Qualitativas: ['mw', 'datum_mw', 'verein', 'wappen', 'player_name']
#
#
# 📋 Tabela Resumo:
#   Variáveis Quantitativas Variáveis Qualitativas
# 0                       x                     mw
# 1                       y               datum_mw
# 2                     age                 verein
# 3               player_id                 wappen
# 4                                    player_name

# %%
exibir_dataset_classificado('dados_partidas',dados_partidas)
# Out:
# 📋 Dataset: dados_partidas
#
# 📊 Total: 634 linhas e 3 colunas
#
# ▶ Variáveis Quantitativas: ['ID da Partida']
# ▶ Variáveis Qualitativas: ['Data', 'Campeonato']
#
#
# 📋 Tabela Resumo:
#   Variáveis Quantitativas Variáveis Qualitativas
# 0           ID da Partida                   Data
# 1                                     Campeonato

# %%
exibir_dataset_classificado('dados_desempenho_jogadores',dados_desempenho_jogadores)
# Out:
# 📋 Dataset: dados_desempenho_jogadores
#
# 📊 Total: 9596 linhas e 22 colunas
#
# ▶ Variáveis Quantitativas: ['possibleGames', 'gamesPlayed', 'goalsScored', 'assists', 'yellowCards', 'secondYellowCards', 'redCards', 'startElevenPercent', 'minutesPlayedPercent', 'goalsContributedPercent', 'concededGoals', 'cleanSheets', 'blockedPenaltyPercent', 'minutesPlayed', 'player_id', 'player_number']
# ▶ Variáveis Qualitativas: ['detailedStatsLink', 'competitionDescription', 'logo', 'nameSeason', 'goalkeeper', 'player_name']
#
#
# 📋 Tabela Resumo:
#     Variáveis Quantitativas  Variáveis Qualitativas
# 0             possibleGames       detailedStatsLink
# 1               gamesPlayed  competitionDescription
# 2               goalsScored                    logo
# 3                   assists              nameSeason
# 4               yellowCards              goalkeeper
# 5         secondYellowCards             player_name
# 6                  redCards
# 7        startElevenPercent
# ...

# %%
exibir_dataset_classificado('dados_jogadores',dados_jogadores)
# Out:
# 📋 Dataset: dados_jogadores
#
# 📊 Total: 2729 linhas e 4 colunas
#
# ▶ Variáveis Quantitativas: ['Nome', 'ID']
# ▶ Variáveis Qualitativas: ['Clube', 'URL do perfil']
#
#
# 📋 Tabela Resumo:
#   Variáveis Quantitativas Variáveis Qualitativas
# 0                    Nome                  Clube
# 1                      ID          URL do perfil

# %%
exibir_dataset_classificado('dados_estatisticas_partidas',dados_estatisticas_partidas)
# Out:
# 📋 Dataset: dados_estatisticas_partidas
#
# 📊 Total: 102690 linhas e 15 colunas
#
# ▶ Variáveis Quantitativas: ['id_partida', 'home_value', 'away_value', 'home_total', 'away_total', 'compare_code']
# ▶ Variáveis Qualitativas: ['data_jogo', 'campeonato', 'home_team', 'away_team', 'period', 'group', 'name', 'key', 'resultado']
#
#
# 📋 Tabela Resumo:
#   Variáveis Quantitativas Variáveis Qualitativas
# 0              id_partida              data_jogo
# 1              home_value             campeonato
# 2              away_value              home_team
# 3              home_total              away_team
# 4              away_total                 period
# 5            compare_code                  group
# 6                                           name
# 7                                            key
# 8                                      resultado

# %%
exibir_dataset_classificado('dados_estatisticas_jogadores',dados_estatisticas_jogadores)
# Out:
# 📋 Dataset: dados_estatisticas_jogadores
#
# 📊 Total: 39861 linhas e 53 colunas
#
# ▶ Variáveis Quantitativas: ['id_partida', 'jerseyNumber', 'height', 'age', 'totalPass', 'accuratePass', 'totalLongBalls', 'accurateLongBalls', 'goalAssist', 'goals', 'minutesPlayed', 'rating', 'touches', 'possessionLostCtrl', 'expectedGoals', 'expectedAssists', 'aerialLost', 'aerialWon', 'duelLost', 'duelWon', 'onTargetScoringAttempt', 'totalClearance', 'totalTackle', 'wasFouled', 'fouls', 'totalCross', 'accurateCross', 'outfielderBlock', 'goodHighClaim', 'savedShotsFromInsideTheBox', 'saves', 'challengeLost', 'totalContest', 'wonContest', 'bigChanceMissed', 'shotOffTarget', 'interceptionWon', 'keyPass', 'dispossessed', 'blockedScoringAttempt', 'bigChanceCreated', 'penaltyWon', 'totalOffside', 'goalsPrevented', 'penaltyConceded']
# ▶ Variáveis Qualitativas: ['data_jogo', 'campeonato', 'team', 'team_name', 'name', 'position', 'country', 'dateOfBirth']
#
#
# 📋 Tabela Resumo:
# ...
