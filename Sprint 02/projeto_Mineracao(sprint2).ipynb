# %% [markdown]
# <h3> * Importando as bibliotecas necessárias para a análise do dataset.</h3>
# <hr>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <h4> * Carregando o(s) dataset(s) do projeto. </h4>

# %%
dataset_valores_jogadores = pd.read_csv('market_value.csv')

dataset_partidas = pd.read_csv('partidas_sofascore.csv')

dataset_performance = pd.read_csv('performance_tm.csv')

dataset_jogadores_time = pd.read_csv('players_tm.csv')

dataset_estatisticas_jogo = pd.read_csv('statistics_game.csv')

dataset_estatisticas_jogadores = pd.read_csv('statistics_player.csv')

# %% [markdown]
# <h4> * Visualizando as primeiras linhas do(s) dataset(s). </h4>
# <hr>

# %%
dataset_valores_jogadores.head()
# Out:
#               x         y     mw      datum_mw                  verein  age  \
# 0  1.202425e+12   50000.0   €50k   Feb 8, 2008  Cruzeiro Esporte Clube   18
# 1  1.229036e+12  200000.0  €200k  Dec 12, 2008  Cruzeiro Esporte Clube   19
# 2  1.254694e+12  800000.0  €800k   Oct 5, 2009  Cruzeiro Esporte Clube   20
# 3  1.271282e+12  600000.0  €600k  Apr 15, 2010  Cruzeiro Esporte Clube   20
# 4  1.275775e+12  300000.0  €300k   Jun 6, 2010  Cruzeiro Esporte Clube   20
#
#                                               wappen  player_id player_name
# 0  https://tmssl.akamaized.net//images/wappen/pro...      68097      Rafael
# 1                                                NaN      68097      Rafael
# 2                                                NaN      68097      Rafael
# 3                                                NaN      68097      Rafael
# 4                                                NaN      68097      Rafael

# %%
dataset_partidas.head()
# Out:
#          Data           Campeonato  ID da Partida
# 0  2024-10-02       Copa do Brasil       12903983
# 1  2024-10-02       Copa do Brasil       12903984
# 2  2024-10-03  Brasileirão Série A       12117263
# 3  2024-10-03  Brasileirão Série A       12117257
# 4  2024-10-03  Brasileirão Série B       12146484

# %%
dataset_performance.head()
# Out:
#                                    detailedStatsLink  \
# 0  /rafael/leistungsdatendetails/spieler/68097/we...
# 1  /rafael/leistungsdatendetails/spieler/68097/we...
# 2  /rafael/leistungsdatendetails/spieler/68097/we...
# 3  /rafael/leistungsdatendetails/spieler/68097/we...
# 4  /rafael/leistungsdatendetails/spieler/68097/we...
#
#          competitionDescription  \
# 0                       Série A
# 1                Copa do Brasil
# 2                 Supercopa Rei
# 3                  Libertadores
# 4  Paulistão A1 - Primeira Fase
#
#                                                 logo nameSeason  \
# 0  https://tmssl.akamaized.net//images/logo/norma...       2024
# 1  https://tmssl.akamaized.net//images/logo/norma...       2024
# 2  https://tmssl.akamaized.net//images/logo/norma...       2024
# 3  https://tmssl.akamaized.net//images/logo/norma...       2024
# 4  https://tmssl.akamaized.net//images/logo/norma...       2024
#
# ...

# %%
dataset_jogadores_time.head()
# Out:
#                      Clube  Nome  \
# 0  São Paulo Futebol Clube   NaN
# 1  São Paulo Futebol Clube   NaN
# 2  São Paulo Futebol Clube   NaN
# 3  São Paulo Futebol Clube   NaN
# 4  São Paulo Futebol Clube   NaN
#
#                                        URL do perfil      ID
# 0  https://www.transfermarkt.com/rafael/profil/sp...   68097
# 1  https://www.transfermarkt.com/jandrei/profil/s...  512344
# 2  https://www.transfermarkt.com/young/profil/spi...  894532
# 3  https://www.transfermarkt.com/nahuel-ferraresi...  466336
# 4  https://www.transfermarkt.com/alan-franco/prof...  503343

# %%
dataset_estatisticas_jogo.head()
# Out:
#    id_partida   data_jogo           campeonato  home_team    away_team period  \
# 0    12117250  2024-09-29  Brasileirão Série A  São Paulo  Corinthians    ALL
# 1    12117250  2024-09-29  Brasileirão Série A  São Paulo  Corinthians    ALL
# 2    12117250  2024-09-29  Brasileirão Série A  São Paulo  Corinthians    ALL
# 3    12117250  2024-09-29  Brasileirão Série A  São Paulo  Corinthians    ALL
# 4    12117250  2024-09-29  Brasileirão Série A  São Paulo  Corinthians    ALL
#
#             group              name  home_value  away_value  home_total  \
# 0  Match overview   Ball possession       53.00       47.00         NaN
# 1  Match overview    Expected goals        2.97        0.84         NaN
# 2  Match overview       Big chances        5.00        0.00         NaN
# 3  Match overview       Total shots       19.00       11.00         NaN
# 4  Match overview  Goalkeeper saves        2.00        5.00         NaN
#
#    away_total  compare_code               key resultado
# ...

# %%
dataset_estatisticas_jogadores.head()
# Out:
#    id_partida   data_jogo           campeonato  team  team_name  \
# 0    12117250  2024-09-29  Brasileirão Série A  home  São Paulo
# 1    12117250  2024-09-29  Brasileirão Série A  home  São Paulo
# 2    12117250  2024-09-29  Brasileirão Série A  home  São Paulo
# 3    12117250  2024-09-29  Brasileirão Série A  home  São Paulo
# 4    12117250  2024-09-29  Brasileirão Série A  home  São Paulo
#
#               name position  jerseyNumber  height    country  ...  \
# 0           Rafael        G          23.0   192.0     Brazil  ...
# 1          Rafinha        D          13.0   172.0     Brazil  ...
# 2  Robert Arboleda        D           5.0   187.0    Ecuador  ...
# 3      Alan Franco        D          28.0   183.0  Argentina  ...
# 4        Welington        D           6.0   170.0     Brazil  ...
#
#   shotOffTarget  interceptionWon  keyPass  dispossessed  \
# 0           NaN              NaN      NaN           NaN
# 1           NaN              NaN      1.0           NaN
# ...

# %% [markdown]
# <h4> * Descobrindo o tamanho do(s) dataset(s) </h4>
# <hr>

# %%
print('Dataset: Valores dos Jogadores')
print('------------------------------')
print('Quantidade de Linhas: {0}'.format(dataset_valores_jogadores.shape[0]))
print('Quantidade de Colunas: {0}'.format(dataset_valores_jogadores.shape[1]))
# Out:
# Dataset: Valores dos Jogadores
# ------------------------------
# Quantidade de Linhas: 33043
# Quantidade de Colunas: 9

# %%
print('Dataset: Dados das Partidas')
print('------------------------------')
print('Quantidade de Linhas: {0}'.format(dataset_partidas.shape[0]))
print('Quantidade de Colunas: {0}'.format(dataset_partidas.shape[1]))

# %%
print('Dataset: Dados das Performances dos Jogadores nas Competições')
print('------------------------------')
print('Quantidade de Linhas: {0}'.format(dataset_performance.shape[0]))
print('Quantidade de Colunas: {0}'.format(dataset_performance.shape[1]))

# %%
print('Dataset: Jogadores dos Clubes')
print('------------------------------')
print('Quantidade de Linhas: {0}'.format(dataset_jogadores_time.shape[0]))
print('Quantidade de Colunas: {0}'.format(dataset_jogadores_time.shape[1]))

# %%
print('Dataset: Estatisticas dos Jogos')
print('------------------------------')
print('Quantidade de Linhas: {0}'.format(dataset_estatisticas_jogo.shape[0]))
print('Quantidade de Colunas: {0}'.format(dataset_estatisticas_jogo.shape[1]))

# %%
print('Dataset: Estatisticas dos Jogadores')
print('------------------------------')
print('Quantidade de Linhas: {0}'.format(dataset_estatisticas_jogadores.shape[0]))
print('Quantidade de Colunas: {0}'.format(dataset_estatisticas_jogadores.shape[1]))
